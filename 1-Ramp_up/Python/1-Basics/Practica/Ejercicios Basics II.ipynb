# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Python Basics II Exercises

# %% [markdown]
# ## Exercise 1
# * Create two numeric variables: an `int` and a `float`
# * Check their types
# * Add them in another new variable
# * What type is the new variable?
# * Delete the first two variables created

# %%
var1 = 4
var2  = 2.0

print(type(var1))
print(type(var2))

var3 = var1 + var2
print(var3)
print(type(var3))

del var3

var1
# Out:
# <class 'int'>
# <class 'float'>
# 6.0
# <class 'float'>
# 4

# %% [markdown]
# ## Exercise 2
# Write a program to convert degrees to radians. You must use `input`. Remember that the conversion is done through
#
# radians = degrees*(pi/180)

# %%
import math
from math import pi

degree = float(input("Insert the degrees: "))
radian = degree*(pi/180)
print(radian)
# Out:
# 0.05235987755982989

# %% [markdown]
# ## Exercise 3
# Write a program that calculates the area of a parallelogram (base x height). Also with `input`

# %%
base = float(input("Insert long base: "))
height = float(input("Longitude of the height: "))

area = base * height
print("The area of the triangle is: ", area)
# Out:
# The area of the triangle is:  150.0

# %% [markdown]
# ## Exercise 4
# We have the following variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Check:
# 1. If A and B are equivalent
# 2. If A and C are NOT equivalent
# 3. If A is greater than C
# 4. If C is less than or equal to A
# 5. If B is NOT equivalent to C

# %%
A = 4
B = "Text"
C = 4.1

print(A==B)
print(A != C)
print(A > C)
print(C <= A)
print(B != C)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ## Exercise 5
# Create a program where two user inputs are collected, and the program output is whether those inputs are equal or not

# %%
inp_1 = input("Insert the first number: ")
inp_2 = input("Insert the second number: ")

print(inp_1 == inp_2)
# Out:
# True

# %% [markdown]
# ## Exercise 6
# Same program as in 5, but this time there must be three inputs and two outputs. One output should tell us if all are equal, and the other if at least two inputs are equal

# %%
inp_1 = input("Insert the first number: ")
inp_2 = input("Insert the second number: ")
inp_3 = input("Insert the third number: ")

print("Are all the numbers equal? ", inp_1 == inp_2 and inp_2 == inp_3 and inp_1 == inp_3)
# Out:
# Are all the numbers equal?  False

# %% [markdown]
# ## Exercise 7
# Create a program that takes two inputs. It must check if their sum is equal, greater than, or less than 10

# %%
inp_1 = float(input("Insert the first number: "))
inp_2 = float(input("Insert the second number: "))

add = inp_1 + inp_2

print("Is greater than 10: ", add > 10)
print("Is less than 10: ", add < 10)
print("Is equal to 10: ", add == 10)
# Out:
# Is greater than 10:  True
# Is less than 10:  False
# Is equal to 10:  False

# %% [markdown]
# ## Exercise 8
# Reason without executing code what output we will get from the following statements
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1. False
# 2. False
# 3. False
# 4. False

# %% [markdown]
# ## Exercise 9
# For this exercise we are going to practice [built-in functions](https://docs.python.org/3/library/functions.html).
#
# 1. Calculate the maximum of the list: [4, 6, 8, -1]
# 2. Sum all elements of the previous list
# 3. Round this float to 3 decimal digits: 63.451256965
# 4. Absolute value of: -74

# %%
numbers= [4,6,8,-1]
maximum_value= max(numbers)
print("Maximum:", maximum_value)

total_sum =sum(numbers)
print("Sum:", total_sum)

rounded_value = round(63.451256965)
print("Rounded value:", rounded_value)

absolute_value =abs(-74)
print("Absolute value:", absolute_value)
# Out:
# Maximum: 8
# Sum: 17
# Rounded value: 63
# Absolute value: 74

# %% [markdown]
# ## Exercise 10
# For the following string you are asked to print the following cases on screen
#
#     "Early birds catch the worm"
#
# 1. Convert it all to uppercase
# 2. Convert it all to lowercase
# 3. Convert to uppercase only the initial of the words
# 4. Create a list by dividing it by its spaces
# 5. Replace commas `,` with semicolons `;`
# 6. Remove lowercase `a` letters

# %%
text= "Early birds catch the worm"

print("Uppercase:", text.upper())

print("Lowercase:", text.lower())

print("Title case:", text.title())

print("Split list:", text.split())

print("replace commas:", text.replace(" ", ","))

print("remove 'a':", text.replace("a", ""))
# Out:
# Uppercase: EARLY BIRDS CATCH THE WORM
# Lowercase: early birds catch the worm
# Title case: Early Birds Catch The Worm
# Split list: ['Early', 'birds', 'catch', 'the', 'worm']
# replace commas: Early,birds,catch,the,worm
# remove 'a': Erly birds ctch the worm

# %% [markdown]
# ## Exercise 11
# 1. Create a list with 3 numeric elements
# 2. Add a fourth element
# 3. Calculate the sum of all
# 4. Delete the second element of the list
# 5. Add another element at position 3 of the list
# 6. Create another list with 4 elements and concatenate it to the one you already had.

# %%
list= [2,3,4]
list.append(5)
print(list)

total_sum = sum(list)
print("Sum:", total_sum)

list.remove (4)
print(list)

list.insert(1, 10)
print(list)

list_1 = [1,2,3]
list_2= list + list_1
print(list_2)
# Out:
# [2, 3, 4, 5]
# Sum: 14
# [2, 3, 5]
# [2, 10, 3, 5]
# [2, 10, 3, 5, 1, 2, 3]
