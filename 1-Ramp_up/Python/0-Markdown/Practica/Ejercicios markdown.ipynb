# %% [markdown]
# ![imagen](./img/ejercicios.png)
# # Markdown
#
# ## Exercise 1
# Let's apply the knowledge we've acquired in this notebook, trying to reproduce the following image in markdown. In the link goes the page: https://www.kaggle.com/
#
# **TIP**: in [this link](https://www.markdownguide.org/basic-syntax/) you have more examples, in case you get stuck with something :)

# %% [markdown]
# ![imagen](./img/md_ejercicio1.png)

# %% [markdown]
# ### Data Scientist Skills
# > **The most important**
# >
# > - Mathematics
# > - Programming
# > - SQL
# > - Python
# >
# > ![imagen](./img/python.png)
# >
# > Another important topic is *Business Intelligence*
# >
# > If you have doubts, you can write me at: <miguel.nievas@thebridgeschool.es>
# >
# > On this page you learn a lot about machine learning: **[page with ML](https://www.kaggle.com/)**

# %% [markdown]
# ## Exercise 2
# For this exercise you're going to create two new elements that we haven't seen in the theory: a table and a formula. Search the web for the syntax and replicate both elements. Pay attention to the white spaces between the table and the formula

# %% [markdown]
# <div style="text-align:center"><img src="./img/md_ejercicio2.png" /></div>

# %% [markdown]
# |Ramp Up|Data Analysis|Machine Learning|Data & Business|
# |:--|:--|:--|:--|
# |Python|EDA|Supervised|Productivization|
# |Statistics|R|Non supervised|Storytelling|
# |SQL|Feat. Eng.|Deep Learning|API|
#
# <br>
# <br>
#
# $$\sqrt{3x-1}+(1+x)^2$$

# %% [markdown]
# |Ramp up | Data Analysis |Machine Learning | Data & Business |
# |--------|---------------|-----------------|-----------------|
# |Python  | EDA           | Supervised      | Productivilizacion|
# |EStadistica| R          | Non supervised  | Storytelling    |
# | SQL    | Feat. Eng.    | Deep Learning   | API             |

# %% [markdown]
# $\sqrt{3x - 1} + (1 + x)^2$
